# %%
import json
import pandas as pd
import numpy as np

# %%
f = open('course_schedules 2022-2023 Record.json', encoding="utf8")

# %%
data = json.load(f)

# %%
data[45]
# Out:
# {'_id': {'$oid': '62ce49e77bed6d1957a462af'},
#  'sessionDetail': {'retake': False,
#   'attendance_mode': 'completed',
#   'startBy': {'$oid': '5fc8ab0d252aa082731f30cd'},
#   'start_time': {'$date': {'$numberLong': '1658379694557'}},
#   'stop_time': {'$date': {'$numberLong': '1658386861011'}}},
#  'zoomDetail': {'meetingStatus': 'completed',
#   'passCode': '84827459',
#   'zoomMeetingId': '82875909223',
#   'zoomStartUrl': 'https://us06web.zoom.us/s/82875909223?zak=eyJ0eXAiOiJKV1QiLCJzdiI6IjAwMDAwMSIsInptX3NrbSI6InptX28ybSIsImFsZyI6IkhTMjU2In0..CIt0-5IFuROZVVJEQmOdkeGLNF47MXXt94sEI8EZd6U',
#   'zoomUuid': 'fk+h8+DJTEGtQR+Ta4HXxQ==',
#   'zoomTotalDuration': '7200'},
#  'rotation': 'no',
# ...

# %%
df = pd.DataFrame(data)

# %%
colu=df.columns

# %% [markdown]
# #

# %%
for col in colu:
    print(col+":")
    print(df[col][45])
    print("""
    
    
    
    -----------------------------------------------------------------------------------------------------------------
    
    
    """)
# Out:
# _id:
# {'$oid': '62ce49e77bed6d1957a462af'}
#
#
#
#
#     -----------------------------------------------------------------------------------------------------------------
#
#
#
# sessionDetail:
# {'retake': False, 'attendance_mode': 'completed', 'startBy': {'$oid': '5fc8ab0d252aa082731f30cd'}, 'start_time': {'$date': {'$numberLong': '1658379694557'}}, 'stop_time': {'$date': {'$numberLong': '1658386861011'}}}
#
#
#
#
#     -----------------------------------------------------------------------------------------------------------------
#
#
#
# zoomDetail:
# ...
